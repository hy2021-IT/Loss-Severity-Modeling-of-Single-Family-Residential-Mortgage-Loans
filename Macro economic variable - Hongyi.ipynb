# %%
import pandas as pd

# %%
data = pd.read_csv("../Data_files/2017Q3.csv")
initial_claims = pd.read_csv("MacroEconomicVariables/InitialClaims.csv")
mortgage_FHA = pd.read_csv("MacroEconomicVariables/Mortgage.csv")
national_HPI = pd.read_csv("MacroEconomicVariables/National_HPI.csv")
state_HPI = pd.read_csv("MacroEconomicVariables/States_HPI.csv")
HPI_master = pd.read_csv("MacroEconomicVariables/HPI_master.csv")
unrate = pd.read_csv("MacroEconomicVariables/UNRATE.csv")

# %%
mortgage_FHA
# Out:
#             DATE  MORTGAGE30US
# 0     1971-04-02          7.33
# 1     1971-04-09          7.31
# 2     1971-04-16          7.31
# 3     1971-04-23          7.31
# 4     1971-04-30          7.29
# ...          ...           ...
# 2737  2023-09-14          7.18
# 2738  2023-09-21          7.19
# 2739  2023-09-28          7.31
# 2740  2023-10-05          7.49
# 2741  2023-10-12          7.57
#
# [2742 rows x 2 columns]

# %%
for i in range(len(mortgage_FHA.DATE)):
    mortgage_FHA.DATE[i] = mortgage_FHA.DATE[i][5:7] + mortgage_FHA.DATE[i][0:4]
    mortgage_FHA.DATE[i] = float(mortgage_FHA.DATE[i])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11316\1554451024.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mortgage_FHA.DATE[i] = mortgage_FHA.DATE[i][5:7] + mortgage_FHA.DATE[i][0:4]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11316\1554451024.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mortgage_FHA.DATE[i] = float(mortgage_FHA.DATE[i])

# %%
mortgage_FHA.DATE = mortgage_FHA.DATE.astype("int")

# %%
mortgage_FHA.DATE
# Out:
# 0        41971
# 1        41971
# 2        41971
# 3        41971
# 4        41971
#          ...
# 2737     92023
# 2738     92023
# 2739     92023
# 2740    102023
# 2741    102023
# Name: DATE, Length: 2742, dtype: int32

# %%
mortgage_FHA_Date = mortgage_FHA.DATE.unique()

# %%
mortgage_FHA_Date
# Out:
# array([ 41971,  51971,  61971,  71971,  81971,  91971, 101971, 111971,
#        121971,  11972,  21972,  31972,  41972,  51972,  61972,  71972,
#         81972,  91972, 101972, 111972, 121972,  11973,  21973,  31973,
#         41973,  51973,  61973,  71973,  81973,  91973, 101973, 111973,
#        121973,  11974,  21974,  31974,  41974,  51974,  61974,  71974,
#         81974,  91974, 101974, 111974, 121974,  11975,  21975,  31975,
#         41975,  51975,  61975,  71975,  81975,  91975, 101975, 111975,
#        121975,  11976,  21976,  31976,  41976,  51976,  61976,  71976,
#         81976,  91976, 101976, 111976, 121976,  11977,  21977,  31977,
#         41977,  51977,  61977,  71977,  81977,  91977, 101977, 111977,
#        121977,  11978,  21978,  31978,  41978,  51978,  61978,  71978,
#         81978,  91978, 101978, 111978, 121978,  11979,  21979,  31979,
#         41979,  51979,  61979,  71979,  81979,  91979, 101979, 111979,
# ...

# %%
mortgage_FHA_Date.sort()

# %%
mortgage_FHA_Date
# Out:
# array([ 11972,  11973,  11974,  11975,  11976,  11977,  11978,  11979,
#         11980,  11981,  11982,  11983,  11984,  11985,  11986,  11987,
#         11988,  11989,  11990,  11991,  11992,  11993,  11994,  11995,
#         11996,  11997,  11998,  11999,  12000,  12001,  12002,  12003,
#         12004,  12005,  12006,  12007,  12008,  12009,  12010,  12011,
#         12012,  12013,  12014,  12015,  12016,  12017,  12018,  12019,
#         12020,  12021,  12022,  12023,  21972,  21973,  21974,  21975,
#         21976,  21977,  21978,  21979,  21980,  21981,  21982,  21983,
#         21984,  21985,  21986,  21987,  21988,  21989,  21990,  21991,
#         21992,  21993,  21994,  21995,  21996,  21997,  21998,  21999,
#         22000,  22001,  22002,  22003,  22004,  22005,  22006,  22007,
#         22008,  22009,  22010,  22011,  22012,  22013,  22014,  22015,
#         22016,  22017,  22018,  22019,  22020,  22021,  22022,  22023,
# ...

# %%
mortgage_FHA = mortgage_FHA.groupby(['DATE'])['MORTGAGE30US'].mean()

# %%
mortgage_FHA
# Out:
# DATE
# 11972     7.4375
# 11973     7.4375
# 11974     8.5400
# 11975     9.4320
# 11976     9.0160
#            ...
# 122018    4.6375
# 122019    3.7200
# 122020    2.6840
# 122021    3.0980
# 122022    6.3640
# Name: MORTGAGE30US, Length: 631, dtype: float64

# %%
# create a dict for mortgage_FHA
mortgage_dict = {'ZB_DTE': mortgage_FHA_Date, "FHA30YearRate": mortgage_FHA}

mortgage_FHA_df = pd.DataFrame(mortgage_dict)

# %%
mortgage_FHA_df
# Out:
#         ZB_DTE  FHA30YearRate
# DATE
# 11972    11972         7.4375
# 11973    11973         7.4375
# 11974    11974         8.5400
# 11975    11975         9.4320
# 11976    11976         9.0160
# ...        ...            ...
# 122018  122018         4.6375
# 122019  122019         3.7200
# 122020  122020         2.6840
# 122021  122021         3.0980
# 122022  122022         6.3640
#
# [631 rows x 2 columns]

# %%
mortgage_FHA_df.to_csv('FHA30YearRate.csv')

# %%
data['ZB_DTE']
# Out:
# 0       42022.0
# 1      112022.0
# 2      112019.0
# 3      112019.0
# 4       22020.0
#          ...
# 739     82019.0
# 740    122021.0
# 741    112022.0
# 742     62018.0
# 743     22023.0
# Name: ZB_DTE, Length: 744, dtype: float64

# %%
float("09.1")
# Out:
# 9.1

# %%
unrate
# Out:
#            DATE  UNRATE
# 0    1948-01-01     3.4
# 1    1948-02-01     3.8
# 2    1948-03-01     4.0
# 3    1948-04-01     3.9
# 4    1948-05-01     3.5
# ..          ...     ...
# 905  2023-06-01     3.6
# 906  2023-07-01     3.5
# 907  2023-08-01     3.8
# 908  2023-09-01     3.8
# 909  2023-10-01     3.9
#
# [910 rows x 2 columns]

# %%
for i in range(len(unrate.DATE)):
    unrate.DATE[i] = unrate.DATE[i][5:7] + unrate.DATE[i][0:4]
    unrate.DATE[i] = float(unrate.DATE[i])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11316\3737680640.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unrate.DATE[i] = unrate.DATE[i][5:7] + unrate.DATE[i][0:4]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11316\3737680640.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unrate.DATE[i] = float(unrate.DATE[i])

# %%
unrate.DATE
# Out:
# 0       11948.0
# 1       21948.0
# 2       31948.0
# 3       41948.0
# 4       51948.0
#          ...
# 905     62023.0
# 906     72023.0
# 907     82023.0
# 908     92023.0
# 909    102023.0
# Name: DATE, Length: 910, dtype: object

# %%
unrate.DATE = unrate.DATE.astype("int")

# %%
unrate.DATE
# Out:
# 0       11948
# 1       21948
# 2       31948
# 3       41948
# 4       51948
#         ...
# 905     62023
# 906     72023
# 907     82023
# 908     92023
# 909    102023
# Name: DATE, Length: 910, dtype: int32

# %%
unrate
# Out:
#        DATE  UNRATE
# 0     11948     3.4
# 1     21948     3.8
# 2     31948     4.0
# 3     41948     3.9
# 4     51948     3.5
# ..      ...     ...
# 905   62023     3.6
# 906   72023     3.5
# 907   82023     3.8
# 908   92023     3.8
# 909  102023     3.9
#
# [910 rows x 2 columns]

# %%
unrate.to_csv('UnemploymentRate.csv')

# %%
state_HPI
# Out:
#            DATE  ALSTHPI  ARSTHPI  AZSTHPI  CASTHPI  COSTHPI  CTSTHPI  \
# 0    1975-01-01    75.22    66.55    60.51    41.69    54.41    62.21
# 1    1975-04-01    72.22    60.23    59.82    42.75    54.85    62.72
# 2    1975-07-01    74.62    64.93    59.36    44.32    54.81    61.80
# 3    1975-10-01    71.70    62.81    56.24    45.76    55.00    61.81
# 4    1976-01-01    77.10    66.91    58.93    47.80    55.10    64.74
# ..          ...      ...      ...      ...      ...      ...      ...
# 189  2022-04-01   460.45   402.61   693.14   922.93   835.95   555.13
# 190  2022-07-01   474.78   416.73   702.91   917.43   827.46   565.42
# 191  2022-10-01   475.18   416.58   680.08   896.33   810.79   564.51
# 192  2023-01-01   481.20   424.70   672.86   892.69   811.18   571.32
# 193  2023-04-01   488.98   434.88   685.70   914.96   832.20   599.74
#
#      DCSTHPI  DESTHPI  FLSTHPI  ...  SDSTHPI  TNSTHPI  TXSTHPI  UTSTHPI  \
# ...

# %%
new_column_names = ['DATE'] + [col[:2] for col in state_HPI.columns[1:]]
state_HPI.columns = new_column_names

# %%
for i in range(len(state_HPI.DATE)):
    state_HPI.DATE[i] = state_HPI.DATE[i][5:7] + state_HPI.DATE[i][0:4]
    state_HPI.DATE[i] = float(state_HPI.DATE[i])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11964\938136901.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_HPI.DATE[i] = state_HPI.DATE[i][5:7] + state_HPI.DATE[i][0:4]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11964\938136901.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_HPI.DATE[i] = float(state_HPI.DATE[i])

# %%
state_HPI.DATE = state_HPI.DATE.astype("int")

# %%
state_HPI.DATE
# Out:
# 0       11975
# 1       41975
# 2       71975
# 3      101975
# 4       11976
#         ...
# 189     42022
# 190     72022
# 191    102022
# 192     12023
# 193     42023
# Name: DATE, Length: 194, dtype: int32

# %%
state_HPI_ori = state_HPI

# %%
state_HPI
# Out:
#        DATE      AL      AR      AZ      CA      CO      CT       DC      DE  \
# 0     11975   75.22   66.55   60.51   41.69   54.41   62.21    47.85   77.03
# 1     41975   72.22   60.23   59.82   42.75   54.85   62.72    47.60   89.61
# 2     71975   74.62   64.93   59.36   44.32   54.81   61.80    47.32  115.70
# 3    101975   71.70   62.81   56.24   45.76   55.00   61.81    54.69   71.67
# 4     11976   77.10   66.91   58.93   47.80   55.10   64.74    53.10   79.54
# ..      ...     ...     ...     ...     ...     ...     ...      ...     ...
# 189   42022  460.45  402.61  693.14  922.93  835.95  555.13  1104.96  642.21
# 190   72022  474.78  416.73  702.91  917.43  827.46  565.42  1095.05  645.59
# 191  102022  475.18  416.58  680.08  896.33  810.79  564.51  1075.99  650.76
# 192   12023  481.20  424.70  672.86  892.69  811.18  571.32  1046.76  663.90
# 193   42023  488.98  434.88  685.70  914.96  832.20  599.74  1062.00  672.17
#
# ...

# %%
state_HPI02 = state_HPI.copy()

# %%
state_HPI02.DATE = state_HPI02.DATE + 10000

# %%
state_HPI02
# Out:
#        DATE      AL      AR      AZ      CA      CO      CT       DC      DE  \
# 0     21975   75.22   66.55   60.51   41.69   54.41   62.21    47.85   77.03
# 1     51975   72.22   60.23   59.82   42.75   54.85   62.72    47.60   89.61
# 2     81975   74.62   64.93   59.36   44.32   54.81   61.80    47.32  115.70
# 3    111975   71.70   62.81   56.24   45.76   55.00   61.81    54.69   71.67
# 4     21976   77.10   66.91   58.93   47.80   55.10   64.74    53.10   79.54
# ..      ...     ...     ...     ...     ...     ...     ...      ...     ...
# 189   52022  460.45  402.61  693.14  922.93  835.95  555.13  1104.96  642.21
# 190   82022  474.78  416.73  702.91  917.43  827.46  565.42  1095.05  645.59
# 191  112022  475.18  416.58  680.08  896.33  810.79  564.51  1075.99  650.76
# 192   22023  481.20  424.70  672.86  892.69  811.18  571.32  1046.76  663.90
# 193   52023  488.98  434.88  685.70  914.96  832.20  599.74  1062.00  672.17
#
# ...

# %%
state_HPI03 = state_HPI02.copy()

# %%
state_HPI03.DATE = state_HPI03.DATE + 10000

# %%
state_HPI03
# Out:
#        DATE      AL      AR      AZ      CA      CO      CT       DC      DE  \
# 0     31975   75.22   66.55   60.51   41.69   54.41   62.21    47.85   77.03
# 1     61975   72.22   60.23   59.82   42.75   54.85   62.72    47.60   89.61
# 2     91975   74.62   64.93   59.36   44.32   54.81   61.80    47.32  115.70
# 3    121975   71.70   62.81   56.24   45.76   55.00   61.81    54.69   71.67
# 4     31976   77.10   66.91   58.93   47.80   55.10   64.74    53.10   79.54
# ..      ...     ...     ...     ...     ...     ...     ...      ...     ...
# 189   62022  460.45  402.61  693.14  922.93  835.95  555.13  1104.96  642.21
# 190   92022  474.78  416.73  702.91  917.43  827.46  565.42  1095.05  645.59
# 191  122022  475.18  416.58  680.08  896.33  810.79  564.51  1075.99  650.76
# 192   32023  481.20  424.70  672.86  892.69  811.18  571.32  1046.76  663.90
# 193   62023  488.98  434.88  685.70  914.96  832.20  599.74  1062.00  672.17
#
# ...

# %%
state_HPI_cat = pd.concat([state_HPI_ori, state_HPI02, state_HPI03])

# %%
state_HPI_cat.sort_values(by=['DATE'])
# Out:
#        DATE      AL      AR      AZ      CA      CO      CT       DC      DE  \
# 0     11975   75.22   66.55   60.51   41.69   54.41   62.21    47.85   77.03
# 4     11976   77.10   66.91   58.93   47.80   55.10   64.74    53.10   79.54
# 8     11977   81.22   72.76   63.51   58.01   64.98   63.99    59.70   89.84
# 12    11978   88.61   80.75   71.32   73.21   76.05   73.68    69.34   85.17
# 16    11979   99.45   91.58   87.05   84.87   91.78   95.30    89.54   86.49
# ..      ...     ...     ...     ...     ...     ...     ...      ...     ...
# 175  122018  317.39  284.34  407.27  641.79  558.45  395.74   879.19  457.63
# 179  122019  336.34  295.84  434.40  663.69  585.16  411.22   910.46  476.60
# 183  122020  359.11  312.23  478.18  699.67  620.34  437.88   951.26  504.33
# 187  122021  422.15  367.95  613.79  834.06  743.97  508.61  1034.71  587.85
# 191  122022  475.18  416.58  680.08  896.33  810.79  564.51  1075.99  650.76
#
# ...

# %%
state_HPI_cat.columns[1:]
# Out:
# Index(['AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'IA',
#        'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO',
#        'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK',
#        'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA', 'WI',
#        'WV', 'WY'],
#       dtype='object')

# %%
State_HPI = pd.melt(state_HPI_cat, id_vars=['DATE'], value_vars= state_HPI_cat.columns[1:],
        var_name='State', value_name='HPI')

# %%
State_HPI
# Out:
#          DATE State     HPI
# 0       11975    AL   75.22
# 1       41975    AL   72.22
# 2       71975    AL   74.62
# 3      101975    AL   71.70
# 4       11976    AL   77.10
# ...       ...   ...     ...
# 29095   62022    WY  440.17
# 29096   92022    WY  451.63
# 29097  122022    WY  450.62
# 29098   32023    WY  451.86
# 29099   62023    WY  455.07
#
# [29100 rows x 3 columns]

# %%
State_HPI.to_csv('State_HPI.csv')
